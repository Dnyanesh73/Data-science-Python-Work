# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import tree
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (14,8)
# %matplotlib inline

# %%
data = pd.read_excel(r"/content/heart_disease.xlsx", sheet_name = 'Heart_disease')

# %%
data
# Out:
#      age   sex               cp  trestbps  chol    fbs           restecg  \
# 0     63  Male   typical angina       145   233   True    lv hypertrophy
# 1     41  Male  atypical angina       135   203  False            normal
# 2     57  Male     asymptomatic       140   192  False            normal
# 3     52  Male   typical angina       118   186  False    lv hypertrophy
# 4     57  Male     asymptomatic       110   201  False            normal
# ..   ...   ...              ...       ...   ...    ...               ...
# 903   53  Male     asymptomatic       125     0  False            normal
# 904   62  Male     asymptomatic       166   170  False  st-t abnormality
# 905   56  Male      non-anginal       170     0  False    lv hypertrophy
# 906   56  Male      non-anginal       144   208   True  st-t abnormality
# 907   57  Male     asymptomatic       142   277   True  st-t abnormality
#
#      thalch  exang  oldpeak        slope               thal  num
# ...

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# cp           object
# trestbps      int64
# chol          int64
# fbs            bool
# restecg      object
# thalch        int64
# exang        object
# oldpeak     float64
# slope        object
# thal         object
# num           int64
# dtype: object

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data.drop_duplicates(keep='first', inplace = True)

# %%
data.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalch       0
# exang        0
# oldpeak     62
# slope        0
# thal         0
# num          0
# dtype: int64

# %%
data['oldpeak'].isnull().sum()/(data.shape[0]) * 100
# Out:
# np.float64(6.835722160970231)

# %% [raw]
# 'oldpeak' column has null value percentage above 5 so we have to impute values.

# %%
data['oldpeak'].fillna(data['oldpeak'].median(), inplace = True)

# %%
data['oldpeak'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### EDA

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# cp           object
# trestbps      int64
# chol          int64
# fbs            bool
# restecg      object
# thalch        int64
# exang        object
# oldpeak     float64
# slope        object
# thal         object
# num           int64
# dtype: object

# %%
data.boxplot(['age','oldpeak','trestbps','thalch','chol'])
# Out:
# <Axes: >

# %%
data.nunique()
# Out:
# age          49
# sex           2
# cp            4
# trestbps     85
# chol        228
# fbs           2
# restecg       3
# thalch      122
# exang         4
# oldpeak      53
# slope         3
# thal          3
# num           5
# dtype: int64

# %%
data.nunique()
# Out:
# age          49
# sex           2
# cp            4
# trestbps     85
# chol        228
# fbs           2
# restecg       3
# thalch      122
# exang         4
# oldpeak      53
# slope         3
# thal          3
# num           5
# dtype: int64

# %%
plt.title('Distribution of Age')
plt.hist(data['age'], bins = 40);

# %% [raw]
# 'age' column is left skewed

# %%
data['sex'].value_counts().plot(kind = 'bar')
plt.title('Gender')
plt.xticks(rotation = 0);

# %% [raw]
# 'sex' column has more males than females

# %%
data['cp'].value_counts().plot(kind = 'bar')
plt.title('Type of Patients')
plt.xticks(rotation = 0);

# %% [raw]
# 'cp' columns has more Asymptomatic patients that means patient with no chest pain, but may still have heart disease.

# %%
plt.title('Distribution of trestbps')
plt.hist(data['trestbps'], bins = 40);

# %% [raw]
# 'trestbps' column has right skewness

# %%
plt.title('Distribution of Chol')
plt.hist(data['chol'], bins = 40);

# %% [raw]
# 'chol' column has right skewness

# %%
data['fbs'].value_counts().plot(kind = 'bar')
plt.title('Fasting Blood Sugar')
plt.xticks(rotation = 0);

# %% [raw]
# 'fbs' column has more false value means the most common is fasting blood sugar ≤ 120 mg/dL (Normal).

# %%
data['restecg'].value_counts().plot(kind = 'bar')
plt.title('Resting Electrocardiographic Results')
plt.xticks(rotation = 0);

# %% [raw]
# 'restecg' column has more normal results.

# %%
plt.hist(data['thalch'], bins = 50)
plt.title('Distribution of maximum heart rate achieved');

# %% [raw]
# 'thalch' column has left skewness

# %%
data['exang'] = data['exang'].replace({'TURE' : True , 'FALSE' : False})

# %%
data['exang'].value_counts().plot(kind = 'bar')
plt.title('Exercise induced angina')
plt.xticks(rotation = 0);

# %% [raw]
# 'exang' column has more false values means most of people has no chest pain during exercise

# %%
plt.hist(data['oldpeak'], bins = 20)
plt.title('Distribution of ST depression');

# %% [raw]
# 'oldpeak' columns has right skewness

# %%
data['slope'].value_counts().plot(kind = 'bar')
plt.title('Frequency of ST Segment Slope Categories')
plt.xticks(rotation = 0);

# %% [raw]
# 'slope' columns has more flat values means that many individuals do not have severe heart disease, but some might have mild or moderate issues.

# %%
data['thal'].value_counts().plot(kind = 'bar')
plt.title('Frequency of Thalassemia Types')
plt.xticks(rotation = 0);

# %% [raw]
# 'thal' column has more normal values that means the majority of people have normal blood flow.

# %%
data['num'].value_counts().plot(kind = 'bar')
plt.title('Frequency of number of stages')
plt.xticks(rotation = 0);

# %% [raw]
# 'num' column has more 0 values that means most of people have no heart disease.

# %%
sns.heatmap(data[['age','oldpeak','trestbps','thalch','chol']].corr(), annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [raw]
# Above heatmap shows that there is no high correlation between features.

# %% [markdown]
# ### Encoding

# %%
data
# Out:
#      age   sex               cp  trestbps  chol    fbs           restecg  \
# 0     63  Male   typical angina       145   233   True    lv hypertrophy
# 1     41  Male  atypical angina       135   203  False            normal
# 2     57  Male     asymptomatic       140   192  False            normal
# 3     52  Male   typical angina       118   186  False    lv hypertrophy
# 4     57  Male     asymptomatic       110   201  False            normal
# ..   ...   ...              ...       ...   ...    ...               ...
# 903   53  Male     asymptomatic       125     0  False            normal
# 904   62  Male     asymptomatic       166   170  False  st-t abnormality
# 905   56  Male      non-anginal       170     0  False    lv hypertrophy
# 906   56  Male      non-anginal       144   208   True  st-t abnormality
# 907   57  Male     asymptomatic       142   277   True  st-t abnormality
#
#      thalch  exang  oldpeak        slope               thal  num
# ...

# %%
data[['fbs', 'exang']] = data[['fbs', 'exang']].astype(int)

# %%
encode_col = ['sex','restecg','cp','slope','thal']
data = pd.get_dummies(data, columns = encode_col, drop_first = True).astype(int)

# %% [raw]
# Scaling is not required for decision tree.

# %%
data
# Out:
#      age  trestbps  chol  fbs  thalch  exang  oldpeak  num  sex_Male  \
# 0     63       145   233    1     150      0        2    0         1
# 1     41       135   203    0     132      0        0    0         1
# 2     57       140   192    0     148      0        0    0         1
# 3     52       118   186    0     190      0        0    0         1
# 4     57       110   201    0     126      1        1    0         1
# ..   ...       ...   ...  ...     ...    ...      ...  ...       ...
# 903   53       125     0    0     120      0        1    4         1
# 904   62       166   170    0     120      1        3    4         1
# 905   56       170     0    0     123      1        2    4         1
# 906   56       144   208    1     105      1        0    4         1
# 907   57       142   277    1     182      0        0    4         1
#
#      restecg_normal  restecg_st-t abnormality  cp_atypical angina  \
# 0                 0                         0                   0
# ...

# %%
x = data.drop('num', axis = 1)
y = data[['num']]

# %% [markdown]
# ### Model Building

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, shuffle = True, random_state = 42)

# %%
dt = DecisionTreeClassifier(criterion = 'gini', random_state = 42)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = dt.predict(x_test)

# %%
print(f'Training Accuracy : {dt.score(x_train, y_train)}')
# Out:
# Training Accuracy : 1.0

# %%
print(f'Testing Accuracy : {dt.score(x_test, y_test)}')
# Out:
# Testing Accuracy : 0.5054945054945055

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.70      0.73        89
#            1       0.35      0.43      0.38        47
#            2       0.21      0.20      0.21        20
#            3       0.17      0.18      0.17        17
#            4       0.43      0.33      0.38         9
#
#     accuracy                           0.51       182
#    macro avg       0.38      0.37      0.37       182
# weighted avg       0.52      0.51      0.51       182

# %%
params = {
    'criterion' : ['entropy','gini'],
    'max_depth' : [3,5,7,9,11],
    'splitter' :['best','random']
}

# %%
grid = GridSearchCV(estimator=DecisionTreeClassifier(), param_grid=params,
                   verbose=1)

# %%
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [3, 5, 7, 9, 11],
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'splitter': 'best'}

# %%
dtr = DecisionTreeClassifier(criterion='gini', max_depth=3, splitter='best', random_state=42)

# %%
dtr.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
y_pred_1 = dtr.predict(x_test)

# %%
dtr.score(x_train,y_train),dtr.score(x_test,y_test)
# Out:
# (0.593103448275862, 0.5274725274725275)

# %% [raw]
# The model is still overfitted so decision tree may not be ideal for this dataset.

# %%
print(classification_report(y_test, y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78        89
#            1       0.40      0.43      0.41        47
#            2       0.11      0.05      0.07        20
#            3       0.08      0.12      0.10        17
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.53       182
#    macro avg       0.27      0.28      0.27       182
# weighted avg       0.48      0.53      0.50       182

# %%
tree.plot_tree(dtr, feature_names=x.columns, filled=True);

# %% [markdown]
# Observation:
# Root Node:
#
# Feature: exang (exercise-induced angina) with a threshold of 0.5.
#
# Gini or impurity: 0.696, with 725 samples.
#
# This shows exang is the most important feature in splitting the data first.
#
# Important Splits:
#
# On the left branch: chol (cholesterol) and thalach (max heart rate achieved) are the next splits.
#
# On the right branch: age, thalach, and trestbps (resting blood pressure) are used.
#
# Leaf Nodes:
#
# Each leaf node shows the predicted value (mean of target in that leaf) and the distribution of samples across different classes or target values.
#
# For example, the leaf [153, 59, 16, 15, 5] indicates predictions for that group of samples.

# %% [markdown]
# exang – most critical for prediction.
#
# chol – important for left branch splits.
#
# age – important for right branch splits.
#
# thalach – splits appear in both branches, moderately important.
#
# trestbps and cp_atypical_angina – less frequently used, lower importance.

# %% [markdown]
# ### Interview Questions

# %% [raw]
# 1) What are some common hyperparameters of decision tree models, and how do they affect the model's        performance?
#
# Ans) Common Hyperparameters:
#      a) max_depth : limits the tree’s depth, controlling complexity.
#      b) min_samples_split : set the minimum samples required to split a node.
#      c) max_features : restricts the number of features considered for splits.
#      d) max_leaf_nodes : limits the number of leaves, controlling tree complexity.
#      e) criterion : gini (Gini impurity), entropy (information gain) for classification and mse
#                     (mean squared error) for regression.
#      - These Hyperparameters reduces overfitting if tune perfectly. It can also improve the accuracy          for classification and r2 (R-Squared) for regression of model.
#
# 2) What is the difference between the Label encoding and One-hot encoding?
#
# Ans) Label encoding and one-hot encoding are both techniques to convert categorical data into numerical      form. Label encoding is used for target column and one-hot encoding is use for categorical              features.
#      a) Label Encoding:
#         - Assigns each unique category into a integer value.
#         - Used when categorical variable has meaningfull order (eg. high, medium, low).
#         - Example: For a feature like Color with categories [Red, Green, Blue], label encoding creates:
#           Red → 0, Green → 1, Blue → 2.
#      b) One-hot encoding:
#         - Creates new binary columns for each category, marking a 1 in the column of the corresponding           category and 0 in others.
#         - Example: For the same Color feature with [Red, Green, Blue], one-hot encoding creates three                      columns:
#                    Color_Red: 1 if Red, else 0
#                    Color_Green: 1 if Green, else 0
#                    Color_Blue: 1 if Blue, else 0
#         - One-hot encoding is used when categorical variables has no meaningful order (eg. Red, Green,           Blue colours). These colours are of same level, no one is considered as high or low.
#         - In ohe we used 'drop_first = True' parameter to avoid multicollinearity.
