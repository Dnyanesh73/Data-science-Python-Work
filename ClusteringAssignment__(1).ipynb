# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.feature_selection import VarianceThreshold
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

# %%
data = pd.read_excel("/content/EastWestAirlines.xlsx",
                     sheet_name='data')

# %%
data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# min       1.000000       0.000000      0.00000           0.000000
# 25%       1.000000    1250.000000      3.00000           0.000000
# 50%       1.000000    7171.000000     12.00000           0.000000
# 75%       1.000000   23800.500000     17.00000         311.000000
# max       5.000000  263685.000000     86.00000       30817.000000
#
#        Flight_trans_12  Days_since_enroll       Award?
# count      3999.000000         3999.00000  3999.000000
# mean          1.373593         4118.55939     0.370343
# std           3.793172         2065.13454     0.482957
# min           0.000000            2.00000     0.000000
# 25%           0.000000         2330.00000     0.000000
# 50%           0.000000         4096.00000     0.000000
# 75%           1.000000         5790.50000     1.000000
# max          53.000000         8296.00000     1.000000

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.drop_duplicates(inplace = True)

# %% [markdown]
# #### Handling Null Values

# %%
data.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %% [raw]
# No null values are present in dataset

# %% [markdown]
# ### EDA

# %%
data.dtypes
# Out:
# ID#                  int64
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award?               int64
# dtype: object

# %%
plt.hist(data['Balance'],bins = 20);
plt.ticklabel_format(style='plain')
plt.title("Distribution of Balance")
plt.xlabel("Balance");

# %% [raw]
# "Balance" column has right skewed data

# %%
plt.hist(data['Qual_miles']);
plt.title("Distribution of Qualifying Miles for Topflight Status")
plt.xlabel("Qual_miles");

# %% [raw]
# "Qual_miles" column has right skewed data

# %%
# values_counts are used to group all same values and sort_index is used to sort index in numerical order
data['cc1_miles'].value_counts().sort_index().plot(kind='bar')
plt.title('Miles Earned via Flyer Credit Card in the Past 12 Months')
plt.xlabel('Miles Earned Category')
plt.xticks(rotation=0);

# %% [raw]
# The most common category is '1'. This suggests that most people have earned very few miles over the past 12 months via flyer credit card.

# %%
data['cc2_miles'].value_counts().sort_index().plot(kind='bar')
plt.title('Miles Earned via Rewards Credit Card in the Past 12 Months')
plt.xlabel('Miles Earned Category')
plt.xticks(rotation=0);

# %% [raw]
# The most common category is '1'. This suggests that most people have earned very few miles over the past 12 months via Rewards credit card.

# %%
data['cc3_miles'].value_counts().sort_index().plot(kind='bar')
plt.title('Miles Earned via Smart Business Credit Card in the Past 12 Months')
plt.xlabel('Miles Earned Category')
plt.xticks(rotation=0);

# %% [raw]
# The most common category is '1'. This suggests that most people have earned very few miles over the past 12 months via smart business credit card.

# %%
plt.title('Distribution of Bonus Miles')
plt.xlabel('Bonus Miles')
plt.hist(data['Bonus_miles']);

# %% [raw]
# "Bonus Miles" column has right skewed data

# %%
plt.title('Distribution of Bonus Trans')
plt.xlabel('Bonus Trans')
plt.hist(data['Bonus_trans']);

# %% [raw]
# "Bonus Trans" column has right skewed data

# %%
plt.title('Distribution of Bonus Flight Miles 12mo')
plt.xlabel('Bonus Flight Miles 12mo')
plt.hist(data['Flight_miles_12mo']);

# %% [raw]
# "Bonus Flight Miles 12mo" column has right skewed data

# %%
plt.title('Distribution of Flight Trans 12')
plt.xlabel('Flight trans 12')
plt.hist(data['Flight_trans_12']);

# %% [raw]
# "Flight trans 12" column has right skewed data

# %%
data['Award?'].value_counts().sort_index().plot(kind='bar')
plt.title('Award')
plt.xticks(rotation=0);

# %% [raw]
# '0' is common category it means that most of people does not get the award

# %%
plt.figure(figsize=(19,8))
data.boxplot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.drop(['ID#','cc1_miles','cc2_miles','cc3_miles','Days_since_enroll','Award?'],axis = 1).corr()
            , annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [raw]
# Above heatmap interpret that some columns are highly correlated to each other

# %%
# Drop irrevelant id column
data.drop('ID#',inplace = True,axis = 1)

# %%
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
# ...      ...
# 3994       1
# 3995       1
# 3996       1
# 3997       0
# 3998       0
#
# [3999 rows x 11 columns]

# %%
plt.figure(figsize=(19,8))
data.boxplot()
# Out:
# <Axes: >

# %%
def capping(data,columns):
    for i in columns:
        Q1 = data[i].quantile(0.25)
        Q3 = data[i].quantile(0.75)
        IQR = Q3 - Q1
        upper_bound = Q3 + (IQR * 1.5)
        lower_bound = Q1 - (IQR * 1.5)
        data[i] = data[i].clip(upper = upper_bound, lower = lower_bound)

# %%
for i in data.columns:
    print(f'Unique values of {i} are {data[i].nunique()}')
# Out:
# Unique values of Balance are 3904
# Unique values of Qual_miles are 164
# Unique values of cc1_miles are 5
# Unique values of cc2_miles are 3
# Unique values of cc3_miles are 5
# Unique values of Bonus_miles are 2734
# Unique values of Bonus_trans are 57
# Unique values of Flight_miles_12mo are 343
# Unique values of Flight_trans_12 are 35
# Unique values of Days_since_enroll are 2820
# Unique values of Award? are 2

# %%
capping(data,data.drop(['Flight_trans_12','Flight_miles_12mo','Qual_miles','cc1_miles','cc2_miles','cc3_miles','Award?'],axis = 1))

# %%
plt.figure(figsize=(19,8))
data.boxplot()
# Out:
# <Axes: >

# %% [raw]
# Boxplot After capping numerical columns except 'Qual_miles' and 'Flight_miles_12mo'

# %%
for i in data.columns:
    print(f'Unique values of {i} are {data[i].nunique()}')
# Out:
# Unique values of Balance are 3639
# Unique values of Qual_miles are 164
# Unique values of cc1_miles are 5
# Unique values of cc2_miles are 3
# Unique values of cc3_miles are 5
# Unique values of Bonus_miles are 2458
# Unique values of Bonus_trans are 39
# Unique values of Flight_miles_12mo are 343
# Unique values of Flight_trans_12 are 35
# Unique values of Days_since_enroll are 2820
# Unique values of Award? are 2

# %% [raw]
# cc1,cc2,cc3 miles, Award are categorical columns

# %%
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     28143.0           0          1          1          1        174.0
# 1     19244.0           0          1          1          1        215.0
# 2     41354.0           0          1          1          1       4123.0
# 3     14776.0           0          1          1          1        500.0
# 4     97752.0           0          4          1          1      43300.0
# ...       ...         ...        ...        ...        ...          ...
# 3994  18476.0           0          1          1          1       8525.0
# 3995  64385.0           0          1          1          1        981.0
# 3996  73597.0           0          3          1          1      25447.0
# 3997  54899.0           0          1          1          1        500.0
# 3998   3016.0           0          1          1          1          0.0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
# ...      ...
# 3994       1
# 3995       1
# 3996       1
# 3997       0
# 3998       0
#
# [3999 rows x 11 columns]

# %%
sc_columns = data.drop(['cc1_miles','cc2_miles','cc3_miles','Award?','Days_since_enroll'], axis = 1).columns.tolist()
sc = StandardScaler()
data[sc_columns] = sc.fit_transform(data[sc_columns])

# %%
data.drop('Days_since_enroll', axis = 1, inplace = True) # It is not important in clustering

# %%
data
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.607258   -0.186299          1          1          1    -0.843091
# 1    -0.758947   -0.186299          1          1          1    -0.840822
# 2    -0.382070   -0.186299          1          1          1    -0.624581
# 3    -0.835106   -0.186299          1          1          1    -0.825052
# 4     0.579265   -0.186299          4          1          1     1.543191
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.772038   -0.186299          1          1          1    -0.381007
# 3995  0.010506   -0.186299          1          1          1    -0.798437
# 3996  0.167530   -0.186299          3          1          1     0.555335
# 3997 -0.151188   -0.186299          1          1          1    -0.825052
# 3998 -1.035562   -0.186299          1          1          1    -0.852718
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Award?
# 0       -1.148854          -0.328603        -0.362168       0
# 1       -1.039133          -0.328603        -0.362168       0
# 2       -0.819689          -0.328603        -0.362168       0
# 3       -1.148854          -0.328603        -0.362168       0
# 4        1.594189           1.154932         0.692490       1
# ...           ...                ...              ...     ...
# 3994    -0.819689          -0.185750        -0.098503       1
# 3995    -0.709967          -0.328603        -0.362168       1
# 3996    -0.380802          -0.328603        -0.362168       1
# 3997    -1.148854           0.028531        -0.098503       0
# 3998    -1.258576          -0.328603        -0.362168       0
#
# [3999 rows x 10 columns]

# %%
# Apply VarianceThreshold to remove low variance features
selector = VarianceThreshold(threshold=0.6)  # Adjust threshold as needed
X_new = selector.fit_transform(data)

# Get selected features
selected_features = data.columns[selector.get_support()]
print(selected_features)
# Out:
# Index(['Balance', 'Qual_miles', 'cc1_miles', 'Bonus_miles', 'Bonus_trans',
#        'Flight_miles_12mo', 'Flight_trans_12'],
#       dtype='object')

# %% [markdown]
# ### Agglomerative Clustering (Ward)

# %%
link = linkage(data[selected_features], method = 'ward')

# %%
plt.figure(figsize=(10, 7))
plt.title('Dendrogram for Hierarchical Clustering (Truncated)')
dendrogram(link, truncate_mode='level', p=5)  # show only top 5 merges
plt.show()

# %% [raw]
# Cut it horizontally to identify number of clusters, Above dendogram has 2 clusters.

# %%
model = AgglomerativeClustering(n_clusters = 2, metric = 'euclidean', linkage = 'ward')
data['Ward_Cluster'] = model.fit_predict(data[selected_features])

# %%
data
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.607258   -0.186299          1          1          1    -0.843091
# 1    -0.758947   -0.186299          1          1          1    -0.840822
# 2    -0.382070   -0.186299          1          1          1    -0.624581
# 3    -0.835106   -0.186299          1          1          1    -0.825052
# 4     0.579265   -0.186299          4          1          1     1.543191
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.772038   -0.186299          1          1          1    -0.381007
# 3995  0.010506   -0.186299          1          1          1    -0.798437
# 3996  0.167530   -0.186299          3          1          1     0.555335
# 3997 -0.151188   -0.186299          1          1          1    -0.825052
# 3998 -1.035562   -0.186299          1          1          1    -0.852718
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Award?  Ward_Cluster
# 0       -1.148854          -0.328603        -0.362168       0             1
# 1       -1.039133          -0.328603        -0.362168       0             1
# 2       -0.819689          -0.328603        -0.362168       0             1
# 3       -1.148854          -0.328603        -0.362168       0             1
# 4        1.594189           1.154932         0.692490       1             0
# ...           ...                ...              ...     ...           ...
# 3994    -0.819689          -0.185750        -0.098503       1             1
# 3995    -0.709967          -0.328603        -0.362168       1             1
# 3996    -0.380802          -0.328603        -0.362168       1             0
# 3997    -1.148854           0.028531        -0.098503       0             1
# 3998    -1.258576          -0.328603        -0.362168       0             1
#
# [3999 rows x 11 columns]

# %%
score = silhouette_score(data[selected_features], data['Ward_Cluster'])

# %%
print("silhouetee_score: ", score)
# Out:
# silhouetee_score:  0.4369857236012968

# %% [markdown]
# ### Agglomerative Clustering (Average)

# %%
link1 = linkage(data[selected_features], method='average')

# %%
plt.figure(figsize=(20, 9))
plt.title('Dendrogram for Hierarchical Clustering')
dendrogram(link1,truncate_mode='lastp');

# %% [raw]
# Above dendogram represents that there are two clusters and it also represents class imbalance.

# %%
model1 = AgglomerativeClustering(n_clusters = 2, metric = 'euclidean', linkage = 'average')
data['Avg_Cluster'] = model1.fit_predict(data[selected_features])

# %%
score = silhouette_score(data[selected_features], data['Avg_Cluster'])

# %%
print("silhouetee_score: ", score)
# Out:
# silhouetee_score:  0.8310271659600628

# %%
data['Avg_Cluster'].value_counts()
# Out:
# Avg_Cluster
# 1    3995
# 0       4
# Name: count, dtype: int64

# %%
data
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.607258   -0.186299          1          1          1    -0.843091
# 1    -0.758947   -0.186299          1          1          1    -0.840822
# 2    -0.382070   -0.186299          1          1          1    -0.624581
# 3    -0.835106   -0.186299          1          1          1    -0.825052
# 4     0.579265   -0.186299          4          1          1     1.543191
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.772038   -0.186299          1          1          1    -0.381007
# 3995  0.010506   -0.186299          1          1          1    -0.798437
# 3996  0.167530   -0.186299          3          1          1     0.555335
# 3997 -0.151188   -0.186299          1          1          1    -0.825052
# 3998 -1.035562   -0.186299          1          1          1    -0.852718
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Award?  Ward_Cluster  \
# 0       -1.148854          -0.328603        -0.362168       0             1
# 1       -1.039133          -0.328603        -0.362168       0             1
# 2       -0.819689          -0.328603        -0.362168       0             1
# 3       -1.148854          -0.328603        -0.362168       0             1
# 4        1.594189           1.154932         0.692490       1             0
# ...           ...                ...              ...     ...           ...
# 3994    -0.819689          -0.185750        -0.098503       1             1
# 3995    -0.709967          -0.328603        -0.362168       1             1
# 3996    -0.380802          -0.328603        -0.362168       1             0
# 3997    -1.148854           0.028531        -0.098503       0             1
# 3998    -1.258576          -0.328603        -0.362168       0             1
#
#       Avg_Cluster
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 3994            1
# 3995            1
# 3996            1
# 3997            1
# 3998            1
#
# [3999 rows x 12 columns]

# %% [markdown]
# ### K-means Clustering

# %%
wcss = []
k = range(1,11)
for i in k:
    kmeans = KMeans(n_clusters=i, random_state = 42)
    kmeans.fit(data[selected_features])
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8, 6))
plt.plot(k, wcss, marker='o', linestyle='-', color='blue')
plt.title('Elbow Method for Optimal Clusters')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Within-Cluster Sum of Squares (WCSS)')
# Out:
# Text(0, 0.5, 'Within-Cluster Sum of Squares (WCSS)')

# %% [raw]
# After 4 the line is decreasing slowly so, the oprtimal clusters should be 3 or 4.

# %%
k_means = KMeans(n_clusters=4, random_state=42)
data['K_means_Cluster'] = k_means.fit_predict(data[selected_features])

# %%
kmeans_silhouette = silhouette_score(data[selected_features], data['K_means_Cluster'])
print(f"K-Means Silhouette Score: {kmeans_silhouette}")
# Out:
# K-Means Silhouette Score: 0.48121361027396947

# %% [markdown]
# ### DBSCAN

# %%
dbscan = DBSCAN(eps=0.5, min_samples=14) # 2 * number of features for min_samples (thumb rule)
data['DBSCAN_Cluster'] = dbscan.fit_predict(data[selected_features])

# %%
labels = data['DBSCAN_Cluster']
# ignoring -1 as it is noise points
dbscan_silhouette = silhouette_score(data[selected_features][labels!=-1], data['DBSCAN_Cluster'][labels!=-1])
print(f"DBSCAN Silhouette Score: {dbscan_silhouette}")
# Out:
# DBSCAN Silhouette Score: 0.3535174595733489
